# %% [markdown]
# <img style="float: left;;" src='alinco.png' /></a>
#
#
# # <center> <font color= #000047> Aprendizaje No Superviado: Kmeans Clustering Imagenes </font> </center>

# %% [markdown]
# Elegir una imagen en blanco y negro de la carpeta `Imagenes` donde se puedan distinguir diferentes figuras para agrupar. Leer la imagen en una matriz de numpy. Definir y reescribir la matriz para tener pixeles en alto o en bajo. Encontrar las coordenadas en donde la matriz tiene pixeles negros. Aplicar el algoritmo de Kmeans sobre el arreglo de coordenadas usando el numero de agrupaciones necesarias de acuerdo a la imagen. Reconstruir la imagen identificando las figuras asociadas a cada grupo.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>NOTA IMPORTANTE!</strong> En cada figura, tabla, o resultado que se incluya, se debe de incluir el código que se utilizó para obtenerlo.  <br> Todas las figuras (si las hubiera) deben de estar comentadas o descritas.</div>

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

image = Image.open("danosorios.jpg").convert("L")
image_np = np.array(image)
threshold = 128
binary_image = np.where(image_np < threshold, 0, 255)
black_pixel_coords = np.column_stack(np.where(binary_image == 0))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagen Binaria')

plt.subplot(1, 2, 2)
plt.scatter(black_pixel_coords[:, 1], black_pixel_coords[:, 0], s=0.5, color='black')
plt.title('Coordenadas de Pixeles Negros')
plt.gca().invert_yaxis()
plt.show()

n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(black_pixel_coords)
labels = kmeans.labels_

plt.figure(figsize=(6, 6))
for i in range(n_clusters):
    cluster = black_pixel_coords[labels == i]
    plt.scatter(cluster[:, 1], cluster[:, 0], s=0.5, label=f'Figura {i+1}')
plt.gca().invert_yaxis()
plt.legend()
plt.title('Figuras Segmentadas por K-means')
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

image = Image.open("zapatos.jpg").convert("L")
image_np = np.array(image)
threshold = 128
binary_image = np.where(image_np < threshold, 0, 255)
black_pixel_coords = np.column_stack(np.where(binary_image == 0))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagen Binaria')

plt.subplot(1, 2, 2)
plt.scatter(black_pixel_coords[:, 1], black_pixel_coords[:, 0], s=0.5, color='black')
plt.title('Coordenadas de Pixeles Negros')
plt.gca().invert_yaxis()
plt.show()

n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(black_pixel_coords)
labels = kmeans.labels_

plt.figure(figsize=(6, 6))
for i in range(n_clusters):
    cluster = black_pixel_coords[labels == i]
    plt.scatter(cluster[:, 1], cluster[:, 0], s=0.5, label=f'Figura {i+1}')
plt.gca().invert_yaxis()
plt.legend()
plt.title('Figuras Segmentadas por K-means')
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

image = Image.open("instrumentos.jpg").convert("L")
image_np = np.array(image)
threshold = 128
binary_image = np.where(image_np < threshold, 0, 255)
black_pixel_coords = np.column_stack(np.where(binary_image == 0))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagen Binaria')

plt.subplot(1, 2, 2)
plt.scatter(black_pixel_coords[:, 1], black_pixel_coords[:, 0], s=0.5, color='black')
plt.title('Coordenadas de Pixeles Negros')
plt.gca().invert_yaxis()
plt.show()

n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(black_pixel_coords)
labels = kmeans.labels_

plt.figure(figsize=(6, 6))
for i in range(n_clusters):
    cluster = black_pixel_coords[labels == i]
    plt.scatter(cluster[:, 1], cluster[:, 0], s=0.5, label=f'Figura {i+1}')
plt.gca().invert_yaxis()
plt.legend()
plt.title('Figuras Segmentadas por K-means')
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

image = Image.open("frutas.jpg").convert("L")
image_np = np.array(image)
threshold = 128
binary_image = np.where(image_np < threshold, 0, 255)
black_pixel_coords = np.column_stack(np.where(binary_image == 0))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagen Binaria')

plt.subplot(1, 2, 2)
plt.scatter(black_pixel_coords[:, 1], black_pixel_coords[:, 0], s=0.5, color='black')
plt.title('Coordenadas de Pixeles Negros')
plt.gca().invert_yaxis()
plt.show()

n_clusters = 6
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(black_pixel_coords)
labels = kmeans.labels_

plt.figure(figsize=(6, 6))
for i in range(n_clusters):
    cluster = black_pixel_coords[labels == i]
    plt.scatter(cluster[:, 1], cluster[:, 0], s=0.5, label=f'Figura {i+1}')
plt.gca().invert_yaxis()
plt.legend()
plt.title('Figuras Segmentadas por K-means')
plt.show()
